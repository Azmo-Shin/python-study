# %%
import pandas as pd

# %%
df1 = pd.read_csv('C:/Users/user/Desktop/workSpace/분석/표준분석모델/천안_전기차/천안 유동인구 7월_sample.csv')

# %%
df2 = pd.read_csv('C:/Users/user/Desktop/workSpace/분석/표준분석모델/천안_전기차/천안 유동인구 8월_sample.csv')

# %%
df3 = pd.read_csv('C:/Users/user/Desktop/workSpace/분석/표준분석모델/천안_전기차/천안 유동인구 9월_sample.csv')

# %%
df4 = [df1, df2, df3]

# %%
df4 = pd.concat(df4)

# %%
df4
# Out:
#        MON              BLOCK_CD        X_COORD       Y_COORD  TMST_00  \
# 0        7  34011320100030000001  956333.991787  1.850829e+06     0.00
# 1        7  34011320100030000001  956333.991787  1.850879e+06     0.00
# 2        7  34011320100030000001  956383.991787  1.850879e+06     0.00
# 3        7  34011320100030000001  956433.991787  1.851029e+06     0.01
# 4        7  34011320100030000001  956533.991787  1.851029e+06     0.00
# ...    ...                   ...            ...           ...      ...
# 77801    9  34011370100010000001  992783.991787  1.862629e+06     0.11
# 77802    9  34011370100010000001  992833.991787  1.862229e+06     0.09
# 77803    9  34011370100010000001  992833.991787  1.862279e+06     0.08
# 77804    9  34011370100010000001  992883.991787  1.862479e+06     0.08
# 77805    9  34011370100010000001  992883.991787  1.862529e+06     0.18
#
#        TMST_01  TMST_02  TMST_03  TMST_04  TMST_05  ...  TMST_14  TMST_15  \
# ...

# %%
df4['total'] = df4.iloc[:,4:27].sum(axis=1)

# %%
df4
# Out:
#        MON              BLOCK_CD        X_COORD       Y_COORD  TMST_00  \
# 0        7  34011320100030000001  956333.991787  1.850829e+06     0.00
# 1        7  34011320100030000001  956333.991787  1.850879e+06     0.00
# 2        7  34011320100030000001  956383.991787  1.850879e+06     0.00
# 3        7  34011320100030000001  956433.991787  1.851029e+06     0.01
# 4        7  34011320100030000001  956533.991787  1.851029e+06     0.00
# ...    ...                   ...            ...           ...      ...
# 77801    9  34011370100010000001  992783.991787  1.862629e+06     0.11
# 77802    9  34011370100010000001  992833.991787  1.862229e+06     0.09
# 77803    9  34011370100010000001  992833.991787  1.862279e+06     0.08
# 77804    9  34011370100010000001  992883.991787  1.862479e+06     0.08
# 77805    9  34011370100010000001  992883.991787  1.862529e+06     0.18
#
#        TMST_01  TMST_02  TMST_03  TMST_04  TMST_05  ...  TMST_15  TMST_16  \
# ...

# %%
df5 = df4[['X_COORD','Y_COORD','total']]

# %%
df5
# Out:
#              X_COORD       Y_COORD  total
# 0      956333.991787  1.850829e+06   1.98
# 1      956333.991787  1.850879e+06   2.47
# 2      956383.991787  1.850879e+06   1.19
# 3      956433.991787  1.851029e+06   4.73
# 4      956533.991787  1.851029e+06   1.57
# ...              ...           ...    ...
# 77801  992783.991787  1.862629e+06  25.50
# 77802  992833.991787  1.862229e+06  23.90
# 77803  992833.991787  1.862279e+06  16.87
# 77804  992883.991787  1.862479e+06  17.67
# 77805  992883.991787  1.862529e+06  38.76
#
# [185438 rows x 3 columns]

# %%
df6 = df5.groupby(['X_COORD','Y_COORD']).sum()

# %%
df6
# Out:
#                              total
# X_COORD       Y_COORD
# 956333.991787 1.850829e+06    2.29
#               1.850879e+06    2.47
#               1.850929e+06    1.45
# 956383.991787 1.850829e+06    1.15
#               1.850879e+06    1.19
# ...                            ...
# 992783.991787 1.862629e+06   25.50
# 992833.991787 1.862229e+06   23.90
#               1.862279e+06   16.87
# 992883.991787 1.862479e+06   65.78
#               1.862529e+06  136.25
#
# [80330 rows x 1 columns]

# %%
df6.to_csv('천안 유동인구.csv')
